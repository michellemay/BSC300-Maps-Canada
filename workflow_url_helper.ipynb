# %%
import requests
from bs4 import BeautifulSoup

base_url = "https://download.geofabrik.de/north-america/"
country = "canada"
response = requests.get(base_url + country + ".html")
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find_all('table', id="subregions")[1]
rows = table.find_all('tr')

# %%
state_cnt = 1
for row in rows:
    for entry in row.find_all('a', href=True):
        link = entry['href']
        if "latest.osm.pbf" in link:
            name = link.split('/')[-1].replace('-latest.osm.pbf', '')
            print("{ name:", name,", geofabrik-url: ",base_url + link, ", state: \"" + str(state_cnt).rjust(2, '0') + "00\"},")
            state_cnt += 1
# Out:
# { name: alberta , geofabrik-url:  https://download.geofabrik.de/north-america/canada/alberta-latest.osm.pbf , state: "0100"},
# { name: british-columbia , geofabrik-url:  https://download.geofabrik.de/north-america/canada/british-columbia-latest.osm.pbf , state: "0200"},
# { name: manitoba , geofabrik-url:  https://download.geofabrik.de/north-america/canada/manitoba-latest.osm.pbf , state: "0300"},
# { name: new-brunswick , geofabrik-url:  https://download.geofabrik.de/north-america/canada/new-brunswick-latest.osm.pbf , state: "0400"},
# { name: newfoundland-and-labrador , geofabrik-url:  https://download.geofabrik.de/north-america/canada/newfoundland-and-labrador-latest.osm.pbf , state: "0500"},
# { name: northwest-territories , geofabrik-url:  https://download.geofabrik.de/north-america/canada/northwest-territories-latest.osm.pbf , state: "0600"},
# { name: nova-scotia , geofabrik-url:  https://download.geofabrik.de/north-america/canada/nova-scotia-latest.osm.pbf , state: "0700"},
# ...
